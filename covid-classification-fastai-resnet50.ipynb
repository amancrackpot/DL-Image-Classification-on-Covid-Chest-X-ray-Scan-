# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import plotly_express as px
import plotly.graph_objects as go
from plotly.subplots import make_subplots
import PIL
import os

# %%
# from fastai.basics import *
from fastai.vision.all import *

# %%
path = '/kaggle/input/covid19-radiography-database/COVID-19_Radiography_Dataset/'

# %% [markdown]
# # Initial Data Checks

# %%
normal_imgs_path_list = get_image_files(path+'Normal')
covid_imgs_path_list = get_image_files(path+'COVID')
viral_imgs_path_list = get_image_files(path+'Viral Pneumonia')

# %%
X = [*normal_imgs_path_list, *covid_imgs_path_list, *viral_imgs_path_list]
len(X)
# Out:
# 15153

# %%
y=pd.Series(data=X)
y=y.apply(lambda x: str(x).split('/')[-2])
y.value_counts().plot.bar()
plt.title('Overall Target Distributions')
plt.show()

# %%
def show_sample(path):
    sample_image = PILImage.create(path) #using matplotlib
    plt.title(sample_image.shape) #.size gives memory usage, so use .shape
    plt.imshow(sample_image, cmap='gray')
    plt.axis("off")
    plt.show()

# %%
show_sample(covid_imgs_path_list[0])

# %%
show_sample(normal_imgs_path_list[0])

# %%
show_sample(viral_imgs_path_list[0])

# %% [markdown]
# # Splitting Data

# %%
from sklearn.model_selection import train_test_split
seed=3
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y, random_state=seed)
# X_train, X_valid, y_train, y_valid = train_test_split(X_train, y_train, test_size=0.2, stratify=y_train, random_state=seed)

# %%
y_train.value_counts(normalize=True)
# Out:
# Normal             0.672579
# COVID              0.238657
# Viral Pneumonia    0.088764
# dtype: float64

# %%
y_test.value_counts(normalize=True)
# Out:
# Normal             0.672715
# COVID              0.238535
# Viral Pneumonia    0.088750
# dtype: float64

# %% [markdown]
# # Creating Dataloaders

# %%
bs=64 #batch size
size=[299,299] #input image size for model
vocab = list(y.unique()) #vocabulary to access string labels

# %%
items = X_train
tfms = [[PILImage.create], [parent_label, Categorize(vocab=vocab, sort=False)]]
splits = TrainTestSplitter(0.2,random_state=3,stratify=y_train)(items)
# splits = L(list(y_train.index)),L(list(y_valid.index))

# %%
ds = Datasets(items=items, tfms=tfms, splits=splits)

# %%
item_tfms = [Resize(size, method=ResizeMethod.Squish), ToTensor()]
batch_tfms = [IntToFloatTensor(), *aug_transforms(max_warp=0, flip_vert=False), Normalize.from_stats(*imagenet_stats)]

# %%
dls = ds.dataloaders(after_item=item_tfms, after_batch=batch_tfms, bs=bs) #complete training set
valid_dls = dls.test_dl(dls.valid_ds.items, with_labels=True) #validation data for metric comparisions
test_dls = dls.test_dl(X_test, with_labels=True) #holdout set

# %%
dls.show_batch()

# %% [markdown]
# # Model Building

# %% [markdown]
# ### I will use transfer learning
# - A pre-trained model is used that was previously trained on a large dataset, typically on a large-scale image-classification task. You either use the pretrained model as is or use transfer learning to customize this model to a given task.
#
# - The intuition behind transfer learning for image classification is that if a model is trained on a large and general enough dataset, this model will effectively serve as a generic model of the visual world. We can then take advantage of these learned feature maps without having to start from scratch.
#
# #### To get best results:
# - We just remove few last layers from pre-trained model and add our own layers, so that it can adapt to our task
# - Then we freeze the pre-trained model and train only our custom 'head'
# - Then we unfreeze and jointly train both the head and body (pre-trained model)

# %%
loss_func = CrossEntropyLossFlat()
metrics = [accuracy]
cbs = [ShowGraphCallback, SaveModelCallback]

# %%
learner = cnn_learner(dls, resnet50, metrics=metrics, cbs=cbs, loss_func=loss_func)
learner.summary()
# Out:
# Downloading: "https://download.pytorch.org/models/resnet50-19c8e357.pth" to /root/.cache/torch/hub/checkpoints/resnet50-19c8e357.pth
#   0%|          | 0.00/97.8M [00:00<?, ?B/s]
# Sequential (Input shape: 64)
# ============================================================================
# Layer (type)         Output Shape         Param #    Trainable
# ============================================================================
#                      64 x 64 x 150 x 150
# Conv2d                                    9408       False
# BatchNorm2d                               128        True
# ReLU
# MaxPool2d
# Conv2d                                    4096       False
# BatchNorm2d                               128        True
# Conv2d                                    36864      False
# BatchNorm2d                               128        True
# ____________________________________________________________________________
#                      64 x 256 x 75 x 75
# Conv2d                                    16384      False
# BatchNorm2d                               512        True
# ReLU
# ____________________________________________________________________________
#                      64 x 256 x 75 x 75
# Conv2d                                    16384      False
# BatchNorm2d                               512        True
# ____________________________________________________________________________
#                      64 x 64 x 75 x 75
# Conv2d                                    16384      False
# BatchNorm2d                               128        True
# Conv2d                                    36864      False
# BatchNorm2d                               128        True
# ____________________________________________________________________________
#                      64 x 256 x 75 x 75
# Conv2d                                    16384      False
# BatchNorm2d                               512        True
# ReLU
# ____________________________________________________________________________
#                      64 x 64 x 75 x 75
# Conv2d                                    16384      False
# BatchNorm2d                               128        True
# Conv2d                                    36864      False
# BatchNorm2d                               128        True
# ____________________________________________________________________________
#                      64 x 256 x 75 x 75
# Conv2d                                    16384      False
# BatchNorm2d                               512        True
# ReLU
# ____________________________________________________________________________
#                      64 x 128 x 75 x 75
# Conv2d                                    32768      False
# BatchNorm2d                               256        True
# ____________________________________________________________________________
#                      64 x 128 x 38 x 38
# Conv2d                                    147456     False
# BatchNorm2d                               256        True
# ____________________________________________________________________________
#                      64 x 512 x 38 x 38
# Conv2d                                    65536      False
# BatchNorm2d                               1024       True
# ReLU
# ____________________________________________________________________________
#                      64 x 512 x 38 x 38
# Conv2d                                    131072     False
# BatchNorm2d                               1024       True
# ____________________________________________________________________________
#                      64 x 128 x 38 x 38
# Conv2d                                    65536      False
# BatchNorm2d                               256        True
# Conv2d                                    147456     False
# BatchNorm2d                               256        True
# ____________________________________________________________________________
#                      64 x 512 x 38 x 38
# Conv2d                                    65536      False
# BatchNorm2d                               1024       True
# ReLU
# ____________________________________________________________________________
#                      64 x 128 x 38 x 38
# Conv2d                                    65536      False
# BatchNorm2d                               256        True
# Conv2d                                    147456     False
# BatchNorm2d                               256        True
# ____________________________________________________________________________
#                      64 x 512 x 38 x 38
# Conv2d                                    65536      False
# BatchNorm2d                               1024       True
# ReLU
# ____________________________________________________________________________
#                      64 x 128 x 38 x 38
# Conv2d                                    65536      False
# BatchNorm2d                               256        True
# Conv2d                                    147456     False
# BatchNorm2d                               256        True
# ____________________________________________________________________________
#                      64 x 512 x 38 x 38
# Conv2d                                    65536      False
# BatchNorm2d                               1024       True
# ReLU
# ____________________________________________________________________________
#                      64 x 256 x 38 x 38
# Conv2d                                    131072     False
# BatchNorm2d                               512        True
# ____________________________________________________________________________
#                      64 x 256 x 19 x 19
# Conv2d                                    589824     False
# BatchNorm2d                               512        True
# ____________________________________________________________________________
#                      64 x 1024 x 19 x 19
# Conv2d                                    262144     False
# BatchNorm2d                               2048       True
# ReLU
# ____________________________________________________________________________
#                      64 x 1024 x 19 x 19
# Conv2d                                    524288     False
# BatchNorm2d                               2048       True
# ____________________________________________________________________________
#                      64 x 256 x 19 x 19
# Conv2d                                    262144     False
# BatchNorm2d                               512        True
# Conv2d                                    589824     False
# BatchNorm2d                               512        True
# ____________________________________________________________________________
#                      64 x 1024 x 19 x 19
# Conv2d                                    262144     False
# BatchNorm2d                               2048       True
# ReLU
# ____________________________________________________________________________
#                      64 x 256 x 19 x 19
# Conv2d                                    262144     False
# BatchNorm2d                               512        True
# Conv2d                                    589824     False
# BatchNorm2d                               512        True
# ____________________________________________________________________________
#                      64 x 1024 x 19 x 19
# Conv2d                                    262144     False
# BatchNorm2d                               2048       True
# ReLU
# ____________________________________________________________________________
#                      64 x 256 x 19 x 19
# Conv2d                                    262144     False
# BatchNorm2d                               512        True
# Conv2d                                    589824     False
# BatchNorm2d                               512        True
# ____________________________________________________________________________
#                      64 x 1024 x 19 x 19
# Conv2d                                    262144     False
# BatchNorm2d                               2048       True
# ReLU
# ____________________________________________________________________________
#                      64 x 256 x 19 x 19
# Conv2d                                    262144     False
# BatchNorm2d                               512        True
# Conv2d                                    589824     False
# BatchNorm2d                               512        True
# ____________________________________________________________________________
#                      64 x 1024 x 19 x 19
# Conv2d                                    262144     False
# BatchNorm2d                               2048       True
# ReLU
# ____________________________________________________________________________
#                      64 x 256 x 19 x 19
# Conv2d                                    262144     False
# BatchNorm2d                               512        True
# Conv2d                                    589824     False
# BatchNorm2d                               512        True
# ____________________________________________________________________________
#                      64 x 1024 x 19 x 19
# Conv2d                                    262144     False
# BatchNorm2d                               2048       True
# ReLU
# ____________________________________________________________________________
#                      64 x 512 x 19 x 19
# Conv2d                                    524288     False
# BatchNorm2d                               1024       True
# ____________________________________________________________________________
#                      64 x 512 x 10 x 10
# Conv2d                                    2359296    False
# BatchNorm2d                               1024       True
# ____________________________________________________________________________
#                      64 x 2048 x 10 x 10
# Conv2d                                    1048576    False
# BatchNorm2d                               4096       True
# ReLU
# ____________________________________________________________________________
#                      64 x 2048 x 10 x 10
# Conv2d                                    2097152    False
# BatchNorm2d                               4096       True
# ____________________________________________________________________________
#                      64 x 512 x 10 x 10
# Conv2d                                    1048576    False
# BatchNorm2d                               1024       True
# Conv2d                                    2359296    False
# BatchNorm2d                               1024       True
# ____________________________________________________________________________
#                      64 x 2048 x 10 x 10
# Conv2d                                    1048576    False
# BatchNorm2d                               4096       True
# ReLU
# ____________________________________________________________________________
#                      64 x 512 x 10 x 10
# Conv2d                                    1048576    False
# BatchNorm2d                               1024       True
# Conv2d                                    2359296    False
# BatchNorm2d                               1024       True
# ____________________________________________________________________________
#                      64 x 2048 x 10 x 10
# Conv2d                                    1048576    False
# BatchNorm2d                               4096       True
# ReLU
# AdaptiveAvgPool2d
# AdaptiveMaxPool2d
# Flatten
# BatchNorm1d                               8192       True
# Dropout
# ____________________________________________________________________________
#                      64 x 512
# Linear                                    2097152    True
# ReLU
# BatchNorm1d                               1024       True
# Dropout
# ____________________________________________________________________________
#                      64 x 3
# Linear                                    1536       True
# ____________________________________________________________________________
#
# Total params: 25,615,936
# Total trainable params: 2,161,024
# Total non-trainable params: 23,454,912
#
# Optimizer used: <function Adam at 0x7f456c459f80>
# Loss function: FlattenedLoss of CrossEntropyLoss()
#
# Model frozen up to parameter group #2
#
# Callbacks:
#   - TrainEvalCallback
#   - Recorder
#   - ProgressCallback
#   - SaveModelCallback
#   - ShowGraphCallback

# %% [markdown]
# ### learning rate finder using callback, this will help decide best learning rate (Implemented by fastai library)
# - The idea is to start with small learning rate (like 1e-4, 1e-3) and increase the learning rate after each mini-batch till loss starts exploding. Once loss starts exploding stop the range test run. Plot the learning rate vs loss plot. Choose the learning rate one order lower than the learning rate where loss is minimum( if loss is low at 0.1, good value to start is 0.01). This is the value where loss is still decreasing. Paper suggests this to be good learning rate value for model.
# ResearchPaper Reference: https://arxiv.org/pdf/1506.01186.pdf

# %%
learner.lr_find()
# Out:
# SuggestedLRs(lr_min=0.012022644281387329, lr_steep=9.12010818865383e-07)

# %% [markdown]
# ### OneCycle Policy using callback (by fastai)
# - Research Paper reference : https://arxiv.org/abs/1803.09820
# - Idea here is to cycle the learning rate and momentum during training between a upper bound and lower bound
# - Motivation for using Cyclical learning rate: Well, experiments have shown, cyclically varying the learning rate between reasonable bounds can actually increase the accuracy of the model in fewer steps. And the reason behind is:
# - higher learning rates help in coming out of local minima and the lower learning rates prevents the training from diverging.
#
# - Author reccomends to use one cycle of 2 steps of equal length, where the maximum learning rate is chosen from LR range test (found previously) and the minimum learning rate is 1/5th or 1/10th of maximum.
# - We pick the cycle length slightly lesser than the total number of epochs to be trained.
# - And in the last remaining iterations, we annihilate learning rate way below lower learning rate value(1/10 th or 1/100 th) [credits](https://towardsdatascience.com/finding-good-learning-rate-and-the-one-cycle-policy-7159fe1db5d6).
#
# - Author found in their experiments that reducing the momentum when learning rate is increasing gives better results.
# ![newplot.png](attachment:newplot.png)

# %%
max_lr = 1e-2
epochs = 1
learner.fit_one_cycle(n_epoch=epochs, lr_max=max_lr)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.206293</td>
#       <td>0.071377</td>
#       <td>0.980206</td>
#       <td>01:41</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with valid_loss value: 0.07137711346149445.

# %%
learner.save('stage-1')
# Out:
# Path('models/stage-1.pth')

# %%
learner.unfreeze() #unfreeze the model for finetuning

# %%
learner.summary()
# Out:
# Sequential (Input shape: 64)
# ============================================================================
# Layer (type)         Output Shape         Param #    Trainable
# ============================================================================
#                      64 x 64 x 150 x 150
# Conv2d                                    9408       True
# BatchNorm2d                               128        True
# ReLU
# MaxPool2d
# Conv2d                                    4096       True
# BatchNorm2d                               128        True
# Conv2d                                    36864      True
# BatchNorm2d                               128        True
# ____________________________________________________________________________
#                      64 x 256 x 75 x 75
# Conv2d                                    16384      True
# BatchNorm2d                               512        True
# ReLU
# ____________________________________________________________________________
#                      64 x 256 x 75 x 75
# Conv2d                                    16384      True
# BatchNorm2d                               512        True
# ____________________________________________________________________________
#                      64 x 64 x 75 x 75
# Conv2d                                    16384      True
# BatchNorm2d                               128        True
# Conv2d                                    36864      True
# BatchNorm2d                               128        True
# ____________________________________________________________________________
#                      64 x 256 x 75 x 75
# Conv2d                                    16384      True
# BatchNorm2d                               512        True
# ReLU
# ____________________________________________________________________________
#                      64 x 64 x 75 x 75
# Conv2d                                    16384      True
# BatchNorm2d                               128        True
# Conv2d                                    36864      True
# BatchNorm2d                               128        True
# ____________________________________________________________________________
#                      64 x 256 x 75 x 75
# Conv2d                                    16384      True
# BatchNorm2d                               512        True
# ReLU
# ____________________________________________________________________________
#                      64 x 128 x 75 x 75
# Conv2d                                    32768      True
# BatchNorm2d                               256        True
# ____________________________________________________________________________
#                      64 x 128 x 38 x 38
# Conv2d                                    147456     True
# BatchNorm2d                               256        True
# ____________________________________________________________________________
#                      64 x 512 x 38 x 38
# Conv2d                                    65536      True
# BatchNorm2d                               1024       True
# ReLU
# ____________________________________________________________________________
#                      64 x 512 x 38 x 38
# Conv2d                                    131072     True
# BatchNorm2d                               1024       True
# ____________________________________________________________________________
#                      64 x 128 x 38 x 38
# Conv2d                                    65536      True
# BatchNorm2d                               256        True
# Conv2d                                    147456     True
# BatchNorm2d                               256        True
# ____________________________________________________________________________
#                      64 x 512 x 38 x 38
# Conv2d                                    65536      True
# BatchNorm2d                               1024       True
# ReLU
# ____________________________________________________________________________
#                      64 x 128 x 38 x 38
# Conv2d                                    65536      True
# BatchNorm2d                               256        True
# Conv2d                                    147456     True
# BatchNorm2d                               256        True
# ____________________________________________________________________________
#                      64 x 512 x 38 x 38
# Conv2d                                    65536      True
# BatchNorm2d                               1024       True
# ReLU
# ____________________________________________________________________________
#                      64 x 128 x 38 x 38
# Conv2d                                    65536      True
# BatchNorm2d                               256        True
# Conv2d                                    147456     True
# BatchNorm2d                               256        True
# ____________________________________________________________________________
#                      64 x 512 x 38 x 38
# Conv2d                                    65536      True
# BatchNorm2d                               1024       True
# ReLU
# ____________________________________________________________________________
#                      64 x 256 x 38 x 38
# Conv2d                                    131072     True
# BatchNorm2d                               512        True
# ____________________________________________________________________________
#                      64 x 256 x 19 x 19
# Conv2d                                    589824     True
# BatchNorm2d                               512        True
# ____________________________________________________________________________
#                      64 x 1024 x 19 x 19
# Conv2d                                    262144     True
# BatchNorm2d                               2048       True
# ReLU
# ____________________________________________________________________________
#                      64 x 1024 x 19 x 19
# Conv2d                                    524288     True
# BatchNorm2d                               2048       True
# ____________________________________________________________________________
#                      64 x 256 x 19 x 19
# Conv2d                                    262144     True
# BatchNorm2d                               512        True
# Conv2d                                    589824     True
# BatchNorm2d                               512        True
# ____________________________________________________________________________
#                      64 x 1024 x 19 x 19
# Conv2d                                    262144     True
# BatchNorm2d                               2048       True
# ReLU
# ____________________________________________________________________________
#                      64 x 256 x 19 x 19
# Conv2d                                    262144     True
# BatchNorm2d                               512        True
# Conv2d                                    589824     True
# BatchNorm2d                               512        True
# ____________________________________________________________________________
#                      64 x 1024 x 19 x 19
# Conv2d                                    262144     True
# BatchNorm2d                               2048       True
# ReLU
# ____________________________________________________________________________
#                      64 x 256 x 19 x 19
# Conv2d                                    262144     True
# BatchNorm2d                               512        True
# Conv2d                                    589824     True
# BatchNorm2d                               512        True
# ____________________________________________________________________________
#                      64 x 1024 x 19 x 19
# Conv2d                                    262144     True
# BatchNorm2d                               2048       True
# ReLU
# ____________________________________________________________________________
#                      64 x 256 x 19 x 19
# Conv2d                                    262144     True
# BatchNorm2d                               512        True
# Conv2d                                    589824     True
# BatchNorm2d                               512        True
# ____________________________________________________________________________
#                      64 x 1024 x 19 x 19
# Conv2d                                    262144     True
# BatchNorm2d                               2048       True
# ReLU
# ____________________________________________________________________________
#                      64 x 256 x 19 x 19
# Conv2d                                    262144     True
# BatchNorm2d                               512        True
# Conv2d                                    589824     True
# BatchNorm2d                               512        True
# ____________________________________________________________________________
#                      64 x 1024 x 19 x 19
# Conv2d                                    262144     True
# BatchNorm2d                               2048       True
# ReLU
# ____________________________________________________________________________
#                      64 x 512 x 19 x 19
# Conv2d                                    524288     True
# BatchNorm2d                               1024       True
# ____________________________________________________________________________
#                      64 x 512 x 10 x 10
# Conv2d                                    2359296    True
# BatchNorm2d                               1024       True
# ____________________________________________________________________________
#                      64 x 2048 x 10 x 10
# Conv2d                                    1048576    True
# BatchNorm2d                               4096       True
# ReLU
# ____________________________________________________________________________
#                      64 x 2048 x 10 x 10
# Conv2d                                    2097152    True
# BatchNorm2d                               4096       True
# ____________________________________________________________________________
#                      64 x 512 x 10 x 10
# Conv2d                                    1048576    True
# BatchNorm2d                               1024       True
# Conv2d                                    2359296    True
# BatchNorm2d                               1024       True
# ____________________________________________________________________________
#                      64 x 2048 x 10 x 10
# Conv2d                                    1048576    True
# BatchNorm2d                               4096       True
# ReLU
# ____________________________________________________________________________
#                      64 x 512 x 10 x 10
# Conv2d                                    1048576    True
# BatchNorm2d                               1024       True
# Conv2d                                    2359296    True
# BatchNorm2d                               1024       True
# ____________________________________________________________________________
#                      64 x 2048 x 10 x 10
# Conv2d                                    1048576    True
# BatchNorm2d                               4096       True
# ReLU
# AdaptiveAvgPool2d
# AdaptiveMaxPool2d
# Flatten
# BatchNorm1d                               8192       True
# Dropout
# ____________________________________________________________________________
#                      64 x 512
# Linear                                    2097152    True
# ReLU
# BatchNorm1d                               1024       True
# Dropout
# ____________________________________________________________________________
#                      64 x 3
# Linear                                    1536       True
# ____________________________________________________________________________
#
# Total params: 25,615,936
# Total trainable params: 25,615,936
# Total non-trainable params: 0
#
# Optimizer used: <function Adam at 0x7f456c459f80>
# Loss function: FlattenedLoss of CrossEntropyLoss()
#
# Model unfrozen
#
# Callbacks:
#   - TrainEvalCallback
#   - Recorder
#   - ProgressCallback
#   - SaveModelCallback
#   - ShowGraphCallback

# %%
learner.lr_find()
# Out:
# SuggestedLRs(lr_min=1.3182566908653825e-05, lr_steep=7.585775847473997e-07)

# %% [markdown]
# - 1e-3 = train all layers using this learning rate
# - slice(1e-3) = last layers are trained with 1e-3 and all the other layers with (1e-3)/3
# - slice(1e-5,1e-3) = Last layers are trained with 1e-5, first layers with 1e-3, and all the others get learning rates that are equally spread between these numbers. For example, if there are three layers, learning rates will be 1e-5,1e-4,1e-3

# %%
max_lr = slice(1e-5,1e-3)
epochs = 10
learner.fit_one_cycle(n_epoch=epochs, lr_max=max_lr)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.111243</td>
#       <td>0.080389</td>
#       <td>0.978557</td>
#       <td>01:59</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.123055</td>
#       <td>0.069581</td>
#       <td>0.978144</td>
#       <td>02:00</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.094725</td>
#       <td>0.039017</td>
#       <td>0.988041</td>
#       <td>01:59</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.071472</td>
#       <td>0.042048</td>
#       <td>0.988454</td>
#       <td>02:00</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.062262</td>
#       <td>0.046454</td>
#       <td>0.983918</td>
#       <td>01:59</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.042235</td>
#       <td>0.033099</td>
#       <td>0.990928</td>
#       <td>01:59</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.030115</td>
#       <td>0.021422</td>
#       <td>0.994639</td>
#       <td>01:59</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.020552</td>
#       <td>0.024254</td>
#       <td>0.994227</td>
#       <td>01:59</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.009806</td>
#       <td>0.023133</td>
#       <td>0.994639</td>
#       <td>01:59</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.008996</td>
#       <td>0.023664</td>
#       <td>0.995052</td>
#       <td>01:59</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with valid_loss value: 0.08038916438817978.
# Better model found at epoch 1 with valid_loss value: 0.06958050280809402.
# Better model found at epoch 2 with valid_loss value: 0.03901679068803787.
# Better model found at epoch 5 with valid_loss value: 0.0330992229282856.
# Better model found at epoch 6 with valid_loss value: 0.021422065794467926.

# %%
learner.validate()
# Out:
# Better model found at epoch 0 with valid_loss value: 0.9946391582489014.
# (#2) [0.021422065794467926,0.9946391582489014]

# %%
learner.save('stage-2')
# Out:
# Path('models/stage-2.pth')

# %% [markdown]
# # Checking Performance on Validation data

# %%
learner.show_results()

# %%
interp = ClassificationInterpretation.from_learner(learner)
interp.plot_top_losses(9, figsize=(9,9))
plt.tight_layout()

# %% [markdown]
# ### - Plots images that gave maximum loss i.e poor performance... can help to see what is going most wrong and how to improve

# %%
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay

def show_inference_results(dls, learner, vocab, tta=False, **tta_kwargs): # report on validation data
    if tta: 
        y_pred_ohe, y_true = learner.tta(dl=dls, **tta_kwargs)
        y_pred = np.argmax(y_pred_ohe.numpy(),axis=1)
        
    else:
        _,y_true,y_pred,losses = learner.get_preds(dl=dls, with_decoded=True, with_loss=True)
    y_pred = [vocab[i] for i in y_pred]
    y_true = [vocab[i] for i in y_true]
    
    if not tta:
        print('-'*60)
        print('Mean Cross Entropy Loss: ',losses.numpy().mean())
        print('-'*60)
        print()
        
    print('-'*60)
    print('Classification Report: ')
    print('-'*60)
    print(classification_report(y_true,y_pred))
    print('-'*60)
    print()
    disp = ConfusionMatrixDisplay(confusion_matrix=confusion_matrix(y_true,y_pred, labels=vocab),
                                  display_labels=vocab)
    disp.plot(cmap='Blues') 
    plt.title('Confusion Matrix')
    plt.show()

# %%
# interp.plot_confusion_matrix(figsize=(5,5))

# %%
show_inference_results(valid_dls, learner, vocab)
# Out:
# ------------------------------------------------------------
# Mean Cross Entropy Loss:  0.021422066
# ------------------------------------------------------------
#
# ------------------------------------------------------------
# Classification Report:
# ------------------------------------------------------------
#                  precision    recall  f1-score   support
#
#           COVID       0.99      0.99      0.99       579
#          Normal       1.00      1.00      1.00      1631
# Viral Pneumonia       0.99      1.00      0.99       215
#
#        accuracy                           0.99      2425
#       macro avg       0.99      0.99      0.99      2425
#    weighted avg       0.99      0.99      0.99      2425
#
# ------------------------------------------------------------

# %%
learner.export() #save model for deployment

# %% [markdown]
# # Testing

# %%
show_inference_results(test_dls, learner, vocab)
# Out:
# ------------------------------------------------------------
# Mean Cross Entropy Loss:  0.022786528
# ------------------------------------------------------------
#
# ------------------------------------------------------------
# Classification Report:
# ------------------------------------------------------------
#                  precision    recall  f1-score   support
#
#           COVID       0.99      0.99      0.99       723
#          Normal       0.99      1.00      0.99      2039
# Viral Pneumonia       0.98      0.97      0.98       269
#
#        accuracy                           0.99      3031
#       macro avg       0.99      0.99      0.99      3031
#    weighted avg       0.99      0.99      0.99      3031
#
# ------------------------------------------------------------

# %% [markdown]
# # Test Time Augmentations

# %% [markdown]
# In practice, we get the predictions n times with the augmentations of the training set and average those. The final predictions are (1-beta) multiplied by this average + beta multiplied by the predictions obtained without the augmentations

# %%
show_inference_results(test_dls, learner, vocab, tta=True, n=4)
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='10' style='width:300px; height:20px; vertical-align: middle;'></progress>
#
#     </div>
# ------------------------------------------------------------
# Classification Report:
# ------------------------------------------------------------
#                  precision    recall  f1-score   support
#
#           COVID       1.00      0.98      0.99       723
#          Normal       0.99      1.00      0.99      2039
# Viral Pneumonia       0.98      0.97      0.98       269
#
#        accuracy                           0.99      3031
#       macro avg       0.99      0.98      0.99      3031
#    weighted avg       0.99      0.99      0.99      3031
#
# ------------------------------------------------------------
